# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# بارگذاری داده 
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# ساخت مدل 
model = keras.Sequential([layers.Input(shape=(28,28)),layers.Flatten(),layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')])

# کامپایل 
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# آموزش 
history = model.fit(x_train, y_train, epochs=5, validation_split=0.1)

#  ارزیابی 
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")

# نمودار آموزش 
plt.figure(figsize=(7,4))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training Progress')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9229 - loss: 0.2730 - val_accuracy: 0.9655 - val_loss: 0.1276
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9649 - loss: 0.1206 - val_accuracy: 0.9713 - val_loss: 0.0966
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9754 - loss: 0.0833 - val_accuracy: 0.9753 - val_loss: 0.0839
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9808 - loss: 0.0622 - val_accuracy: 0.9768 - val_loss: 0.0814
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9850 - loss: 0.0485 - val_accuracy: 0.9787 - val_loss: 0.0792
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9732 - loss: 0.0831
# Test Accuracy: 0.9732
